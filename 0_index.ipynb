# %% [markdown]
#  Identificación de patrones topológicos en los diferentes estadios de la enfermedad de alzheimer
# mediante análisis de redes complejas: un estudio basado en rs-fMR

# %% [markdown]
# #### Scripts:

# %% [markdown]
# 1_BOLD_parcel_matrix.ipynb
#
# Lectura de datos .npz (series de tiempo * ROIS Seitzman)
# * 63 AD
# * 64 CNAD
# * 58 MCI
# * 58 CN MCI
#
# Preprocesado de datos y promedio por grupo cognitivo
#
# Cálculo correlación por coherencia multitaper generando matrices de correlación 300x300 roi's

# %% [markdown]
# 2_Gaphs_plot.ipybn
#
# * Gráficos conectomas de las matrices de correlación

# %% [markdown]
# 3_ Connectivity_Metrics
#
# Cálculo de métricas locales y globales sobre las matrices
#
# * 'Avg Path Length'
# * 'Global Efficiency'
# * 'Avg Clustering Coefficient'
# * 'Avg Betweenness Centrality'
# * 'Avg Closeness Centrality'
# * Modularity'
# * 'Transitivity'
#
# pendiente Armonizar y adaptar matrices a métricas puntuales (grafos dirigidos, completamente conectados)
